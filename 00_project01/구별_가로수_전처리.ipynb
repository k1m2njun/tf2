# %%
import pandas as pd

# %%
tree_amount = pd.read_csv('가로수+현황_20220926223730.csv', encoding='utf-8-sig')
tree_amount.drop(columns='자치구별(1)', inplace=True)
tree_amount
# Out:
#     자치구별(2)  2020  2020.1  2020.2 2020.3 2020.4 2020.5 2020.6  2020.7 2020.8  \
# 0   자치구별(2)   노선수      수량      종별     종별     종별     종별     종별      종별     종별
# 1   자치구별(2)    소계      소계    은행나무  양버즘나무   느티나무   왕벚나무  은단풍나무  메타세콰이어   회화나무
# 2        소계  1482  305086  106205  59776  37789  35583    366    5148   7575
# 3       종로구    62    7435    4075   1067    698    422      -       1    144
# 4        중구    48    8300    3629    162    459    305      -       -    174
# 5       용산구    39    7821    4378   1365    471    261      -       -     41
# 6       성동구    38    7927    1037   2102   1906    602     29      48    294
# 7       광진구    28    7238    1244   2318   1062    931      -       -    153
# 8      동대문구    43   10676    3869   3215    849    747      -      62    143
# 9       중랑구    59    8270    2765   2483    348    461      -      74      -
# 10      성북구    80    8485    2533   1188   1000   1757      8      65     38
# ...

# %%
tree_amount = tree_amount.rename(columns=tree_amount.iloc[1])
tree_amount
# Out:
#     자치구별(2)    소계      소계    은행나무  양버즘나무   느티나무   왕벚나무  은단풍나무  메타세콰이어  회화나무  \
# 0   자치구별(2)   노선수      수량      종별     종별     종별     종별     종별      종별    종별
# 1   자치구별(2)    소계      소계    은행나무  양버즘나무   느티나무   왕벚나무  은단풍나무  메타세콰이어  회화나무
# 2        소계  1482  305086  106205  59776  37789  35583    366    5148  7575
# 3       종로구    62    7435    4075   1067    698    422      -       1   144
# 4        중구    48    8300    3629    162    459    305      -       -   174
# 5       용산구    39    7821    4378   1365    471    261      -       -    41
# 6       성동구    38    7927    1037   2102   1906    602     29      48   294
# 7       광진구    28    7238    1244   2318   1062    931      -       -   153
# 8      동대문구    43   10676    3869   3215    849    747      -      62   143
# 9       중랑구    59    8270    2765   2483    348    461      -      74     -
# 10      성북구    80    8485    2533   1188   1000   1757      8      65    38
# ...

# %%
tree_amount.to_csv('tree_amount_2020.csv', encoding='utf-8-sig')

# %%
tree_amount = pd.read_csv('tree_amount_2020.csv', header=2)

# %%
tree_amount
# Out:
#      1  자치구별(2)    소계    소계.1    은행나무  양버즘나무   느티나무   왕벚나무 은단풍나무 메타세콰이어  ...  \
# 0    2       소계  1482  305086  106205  59776  37789  35583   366   5148  ...
# 1    3      종로구    62    7435    4075   1067    698    422     -      1  ...
# 2    4       중구    48    8300    3629    162    459    305     -      -  ...
# 3    5      용산구    39    7821    4378   1365    471    261     -      -  ...
# 4    6      성동구    38    7927    1037   2102   1906    602    29     48  ...
# 5    7      광진구    28    7238    1244   2318   1062    931     -      -  ...
# 6    8     동대문구    43   10676    3869   3215    849    747     -     62  ...
# 7    9      중랑구    59    8270    2765   2483    348    461     -     74  ...
# 8   10      성북구    80    8485    2533   1188   1000   1757     8     65  ...
# 9   11      강북구    31    7346    3067    878    322    496   271      -  ...
# 10  12      도봉구    63    9449    4811    292    778   2092     6     61  ...
# ...

# %%
tree_amount.rename(columns={'자치구별(2)':'시군구명', '소계':'노선수', '소계.1':'소계'}, inplace=True)

# %%
tree_amount = tree_amount.drop(columns='1')

# %%
tree_amount.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구명    28 non-null     object
#  1   노선수     28 non-null     int64
#  2   소계      28 non-null     int64
#  3   은행나무    28 non-null     int64
#  4   양버즘나무   28 non-null     int64
#  5   느티나무    28 non-null     int64
#  6   왕벚나무    28 non-null     object
#  7   은단풍나무   28 non-null     object
#  8   메타세콰이어  28 non-null     object
#  9   회화나무    28 non-null     object
#  10  가죽나무    28 non-null     object
#  11  감나무     28 non-null     object
#  12  수양버들    28 non-null     object
#  13  튜울립나무   28 non-null     object
#  14  칠엽수     28 non-null     object
#  15  포플러     28 non-null     object
#  16  느릅나무    28 non-null     object
#  17  살구나무    28 non-null     object
#  18  무궁화     28 non-null     object
#  19  소나무     28 non-null     object
#  20  목련      28 non-null     object
# ...

# %%
tree_amount['왕벚나무'] = pd.to_numeric(tree_amount['왕벚나무'], errors='coerce')
tree_amount['은단풍나무'] = pd.to_numeric(tree_amount['은단풍나무'], errors='coerce')
tree_amount['메타세콰이어'] = pd.to_numeric(tree_amount['메타세콰이어'], errors='coerce')
tree_amount['회화나무'] = pd.to_numeric(tree_amount['회화나무'], errors='coerce')
tree_amount['가죽나무'] = pd.to_numeric(tree_amount['가죽나무'], errors='coerce')
tree_amount['감나무'] = pd.to_numeric(tree_amount['감나무'], errors='coerce')
tree_amount['수양버들'] = pd.to_numeric(tree_amount['수양버들'], errors='coerce')
tree_amount['튜울립나무'] = pd.to_numeric(tree_amount['튜울립나무'], errors='coerce')
tree_amount['칠엽수'] = pd.to_numeric(tree_amount['칠엽수'], errors='coerce')
tree_amount['포플러'] = pd.to_numeric(tree_amount['포플러'], errors='coerce')
tree_amount['느릅나무'] = pd.to_numeric(tree_amount['느릅나무'], errors='coerce')
tree_amount['살구나무'] = pd.to_numeric(tree_amount['살구나무'], errors='coerce')
tree_amount['무궁화'] = pd.to_numeric(tree_amount['무궁화'], errors='coerce')
tree_amount['소나무'] = pd.to_numeric(tree_amount['소나무'], errors='coerce')
tree_amount['목련'] = pd.to_numeric(tree_amount['목련'], errors='coerce')
tree_amount['기타'] = pd.to_numeric(tree_amount['기타'], errors='coerce')

# %%
tree_amount.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구명    28 non-null     object
#  1   노선수     28 non-null     int64
#  2   소계      28 non-null     int64
#  3   은행나무    28 non-null     int64
#  4   양버즘나무   28 non-null     int64
#  5   느티나무    28 non-null     int64
#  6   왕벚나무    27 non-null     float64
#  7   은단풍나무   7 non-null      float64
#  8   메타세콰이어  21 non-null     float64
#  9   회화나무    23 non-null     float64
#  10  가죽나무    7 non-null      float64
#  11  감나무     15 non-null     float64
#  12  수양버들    6 non-null      float64
#  13  튜울립나무   12 non-null     float64
#  14  칠엽수     16 non-null     float64
#  15  포플러     3 non-null      float64
#  16  느릅나무    5 non-null      float64
#  17  살구나무    8 non-null      float64
#  18  무궁화     12 non-null     float64
#  19  소나무     21 non-null     float64
#  20  목련      7 non-null      float64
# ...

# %%
tree_amount
# Out:
#        시군구명   노선수      소계    은행나무  양버즘나무   느티나무     왕벚나무  은단풍나무  메타세콰이어  \
# 0        소계  1482  305086  106205  59776  37789  35583.0  366.0  5148.0
# 1       종로구    62    7435    4075   1067    698    422.0    NaN     1.0
# 2        중구    48    8300    3629    162    459    305.0    NaN     NaN
# 3       용산구    39    7821    4378   1365    471    261.0    NaN     NaN
# 4       성동구    38    7927    1037   2102   1906    602.0   29.0    48.0
# 5       광진구    28    7238    1244   2318   1062    931.0    NaN     NaN
# 6      동대문구    43   10676    3869   3215    849    747.0    NaN    62.0
# 7       중랑구    59    8270    2765   2483    348    461.0    NaN    74.0
# 8       성북구    80    8485    2533   1188   1000   1757.0    8.0    65.0
# 9       강북구    31    7346    3067    878    322    496.0  271.0     NaN
# 10      도봉구    63    9449    4811    292    778   2092.0    6.0    61.0
# 11      노원구   100   13276    6104   2714   1130   1913.0    NaN   292.0
# ...

# %%
tree_amount.to_csv('전처리)구별_가로수_2020.csv', encoding='utf-8-sig')
