#  21  대전광역시.2    25 non-null     object
#  22  울산광역시      25 non-null     object
#  23  울산광역시.1    25 non-null     object
#  24  울산광역시.2    25 non-null     object
#  25  세종특별자치시    10 non-null     object
#  26  세종특별자치시.1  10 non-null     object
#  27  세종특별자치시.2  10 non-null     object
#  28  경기도        25 non-null     object
#  29  경기도.1      25 non-null     object
#  30  경기도.2      25 non-null     object
#  31  강원도        25 non-null     object
#  32  강원도.1      25 non-null     object
#  33  강원도.2      25 non-null     object
#  34  충청북도       25 non-null     object
#  35  충청북도.1     25 non-null     object
#  36  충청북도.2     25 non-null     object
#  37  충청남도       25 non-null     object
#  38  충청남도.1     25 non-null     object
#  39  충청남도.2     25 non-null     object
#  40  전라북도       25 non-null     object
#  41  전라북도.1     25 non-null     object
#  42  전라북도.2     25 non-null     object
#  43  전라남도       25 non-null     object
#  44  전라남도.1     25 non-null     object
#  45  전라남도.2     25 non-null     object
#  46  경상북도       25 non-null     object
#  47  경상북도.1     25 non-null     object
#  48  경상북도.2     25 non-null     object
#  49  경상남도       25 non-null     object
#  50  경상남도.1     25 non-null     object
#  51  경상남도.2     25 non-null     object
#  52  제주특별자치도    25 non-null     object
#  53  제주특별자치도.1  25 non-null     object
#  54  제주특별자치도.2  25 non-null     object
# dtypes: int32(1), object(54)
# memory usage: 10.8+ KB

# %%
df_b.plot(x='시점',y='출생자(명)',kind='line')
# Out:
# <AxesSubplot:xlabel='시점'>

# %%
df_d = pd.read_csv('사망자수__조사망률__기대수명_20220925215132.csv', encoding='euc-kr')
df_d
# Out:
#          시점  사망자수(명)  조사망률(천명당) 기대수명(출생시 기대여명) 기대수명(출생시 기대여명) - 남  \
# 0      1997   244693        5.3           74.7               70.7
# 1      1998   245825        5.2           75.1               71.2
# 2      1999   247734        5.3           75.5               71.8
# 3      2000   248740        5.2           76.0               72.3
# 4      2001   243813        5.1           76.5               72.9
# 5      2002   247524        5.1           76.8               73.4
# 6      2003   246463        5.1           77.3               73.8
# 7      2004   246220        5.1           77.8               74.3
# 8      2005   245874        5.1           78.2               74.9
# 9      2006   244162        5.0           78.8               75.4
# 10     2007   246482        5.0           79.2               75.9
# 11     2008   246113        5.0           79.6               76.2
# 12     2009   246942        5.0           80.0               76.7
# 13     2010   255405        5.1           80.2               76.8
# 14     2011   257396        5.1           80.6               77.3
# 15     2012   267221        5.3           80.9               77.6
# 16     2013   266257        5.3           81.4               78.1
# 17     2014   267692        5.3           81.8               78.6
# 18     2015   275895        5.4           82.1               79.0
# 19     2016   280827        5.5           82.4               79.3
# 20     2017   285534        5.6           82.7               79.7
# 21     2018   298820        5.8           82.7               79.7
# 22     2019   295110        5.7           83.3               80.3
# 23     2020   304948        5.9           83.5               80.5
# 24  2021 p)   317800        6.2              -                  -
#
#    기대수명(출생시 기대여명) - 여
# 0                78.7
# 1                79.0
# 2                79.2
# 3                79.7
# 4                80.1
# 5                80.3
# 6                80.8
# 7                81.2
# 8                81.6
# 9                82.1
# 10               82.5
# 11               83.0
# 12               83.4
# 13               83.6
# 14               84.0
# 15               84.2
# 16               84.6
# 17               85.0
# 18               85.2
# 19               85.4
# 20               85.7
# 21               85.7
# 22               86.3
# 23               86.5
# 24                  -

# %%
df_d.plot(x='시점',y='사망자수(명)',kind='line')
# Out:
# <AxesSubplot:xlabel='시점'>

# %%
import seaborn as sns

# %%
df_bd = pd.merge(df_b, df_d, left_on='시점', right_on='시점', how='outer')
df_bd = df_bd[['시점', '출생자(명)', '사망자수(명)']]
df_bd.drop([24, 25], inplace=True) # 21년도 데이터 삭제
df_bd
# Out:
#       시점    출생자(명)   사망자수(명)
# 0   1997  675394.0  244693.0
# 1   1998  641594.0  245825.0
# 2   1999  620668.0  247734.0
# 3   2000  640089.0  248740.0
# 4   2001  559934.0  243813.0
# 5   2002  496911.0  247524.0
# 6   2003  495036.0  246463.0
# 7   2004  476958.0  246220.0
# 8   2005  438707.0  245874.0
# 9   2006  451759.0  244162.0
# 10  2007  496822.0  246482.0
# 11  2008  465892.0  246113.0
# 12  2009  444849.0  246942.0
# 13  2010  470171.0  255405.0
# 14  2011  471265.0  257396.0
# 15  2012  484550.0  267221.0
# 16  2013  436455.0  266257.0
# 17  2014  435435.0  267692.0
# 18  2015  438420.0  275895.0
# 19  2016  406243.0  280827.0
# 20  2017  357771.0  285534.0
# 21  2018  326822.0  298820.0
# 22  2019  302676.0  295110.0
# 23  2020  272337.0  304948.0

# %%
df_bd = df_bd.set_index('시점')
df_bd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_bd = df_bd.set_index('시점')
#       2 df_bd
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['시점'] are in the columns"

# %%
df_bd
# Out:
#           출생자(명)    사망자수(명)
# 시점
# 1997    675394.0   244693.0
# 1998   1316988.0   490518.0
# 1999   1937656.0   738252.0
# 2000   2577745.0   986992.0
# 2001   3137679.0  1230805.0
# 2002   3634590.0  1478329.0
# 2003   4129626.0  1724792.0
# 2004   4606584.0  1971012.0
# 2005   5045291.0  2216886.0
# 2006   5497050.0  2461048.0
# 2007   5993872.0  2707530.0
# 2008   6459764.0  2953643.0
# 2009   6904613.0  3200585.0
# 2010   7374784.0  3455990.0
# 2011   7846049.0  3713386.0
# 2012   8330599.0  3980607.0
# 2013   8767054.0  4246864.0
# 2014   9202489.0  4514556.0
# 2015   9640909.0  4790451.0
# 2016  10047152.0  5071278.0
# 2017  10404923.0  5356812.0
# 2018  10731745.0  5655632.0
# 2019  11034421.0  5950742.0
# 2020  11306758.0  6255690.0

# %%
df_bd.plot()
# Out:
# <AxesSubplot:xlabel='시점'>

# %%
df_bd = df_bd.cumsum()

# %%
import seaborn as sns

# %%
sns.displot(data=df_bd)

# %%
# data = pd.pivot_table(df_bd, index=['시점'], columns=['전국(명)', '사망자수(명)']).plot(x='사망자수(명)',y=['전국(명)'], kind='line')

# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)


df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
dates = pd.date_range("20130101", periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.779058  0.205012 -0.564650  1.043922
# 2013-01-02  0.967842  0.272362 -0.859027 -0.773199
# 2013-01-03 -0.446213 -0.514641  0.480547  1.279540
# 2013-01-04  0.848874  0.171807  1.497093 -0.939010
# 2013-01-05  0.450029 -1.042384  0.765347  1.127244
# 2013-01-06 -0.757226  0.145115  0.211907  0.528767

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.779058  0.205012 -0.564650  1.043922
# 2013-01-02  0.967842  0.272362 -0.859027 -0.773199
# 2013-01-03 -0.446213 -0.514641  0.480547  1.279540
# 2013-01-04  0.848874  0.171807  1.497093 -0.939010
# 2013-01-05  0.450029 -1.042384  0.765347  1.127244
# 2013-01-06 -0.757226  0.145115  0.211907  0.528767

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
df["F"] = s1

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.779058  0.205012 -0.564650  1.043922  NaN
# 2013-01-02  0.967842  0.272362 -0.859027 -0.773199  1.0
# 2013-01-03 -0.446213 -0.514641  0.480547  1.279540  2.0
# 2013-01-04  0.848874  0.171807  1.497093 -0.939010  3.0
# 2013-01-05  0.450029 -1.042384  0.765347  1.127244  4.0
# 2013-01-06 -0.757226  0.145115  0.211907  0.528767  5.0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.779058  0.205012 -0.564650  5  NaN
# 2013-01-02  0.967842  0.272362 -0.859027  5  1.0
# 2013-01-03 -0.446213 -0.514641  0.480547  5  2.0
# 2013-01-04  0.848874  0.171807  1.497093  5  3.0
# 2013-01-05  0.450029 -1.042384  0.765347  5  4.0
# 2013-01-06 -0.757226  0.145115  0.211907  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01 -0.779058 -0.205012 -0.564650 -5  NaN
# 2013-01-02 -0.967842 -0.272362 -0.859027 -5 -1.0
# 2013-01-03 -0.446213 -0.514641 -0.480547 -5 -2.0
# 2013-01-04 -0.848874 -0.171807 -1.497093 -5 -3.0
# 2013-01-05 -0.450029 -1.042384 -0.765347 -5 -4.0
# 2013-01-06 -0.757226 -0.145115 -0.211907 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1
# Out:
#                    A         B         C  D    F   E
# 2013-01-01  0.779058  0.205012 -0.564650  5  NaN NaN
# 2013-01-02  0.967842  0.272362 -0.859027  5  1.0 NaN
# 2013-01-03 -0.446213 -0.514641  0.480547  5  2.0 NaN
# 2013-01-04  0.848874  0.171807  1.497093  5  3.0 NaN

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.779058  0.205012 -0.564650  5  NaN  1.0
# 2013-01-02  0.967842  0.272362 -0.859027  5  1.0  1.0
# 2013-01-03 -0.446213 -0.514641  0.480547  5  2.0  NaN
# 2013-01-04  0.848874  0.171807  1.497093  5  3.0  NaN

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.779058  0.205012 -0.564650  5  NaN
# 2013-01-02  0.967842  0.272362 -0.859027  5  1.0
# 2013-01-03 -0.446213 -0.514641  0.480547  5  2.0
# 2013-01-04  0.848874  0.171807  1.497093  5  3.0
# 2013-01-05  0.450029 -1.042384  0.765347  5  4.0
# 2013-01-06 -0.757226  0.145115  0.211907  5  5.0

# %%
df.mean(1)
# Out:
# 2013-01-01    1.354855
# 2013-01-02    1.276235
# 2013-01-03    1.303939
# 2013-01-04    2.103555
# 2013-01-05    1.834599
# 2013-01-06    1.919959
# Freq: D, dtype: float64

# %%
pd.Series([1, 3, 5, np.nan, 6, 8], index=dates)
# Out:
# 2013-01-01    1.0
# 2013-01-02    3.0
# 2013-01-03    5.0
# 2013-01-04    NaN
# 2013-01-05    6.0
# 2013-01-06    8.0
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index").shift(2)
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03       NaN       NaN       NaN  NaN  NaN
# 2013-01-04       NaN       NaN       NaN  NaN  NaN
# 2013-01-05 -1.446213 -1.514641 -0.519453  4.0  1.0
# 2013-01-06 -2.151126 -2.828193 -1.502907  2.0  0.0

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.779058  0.205012 -0.564650  5  NaN
# 2013-01-02  0.967842  0.272362 -0.859027  5  1.0
# 2013-01-03 -0.446213 -0.514641  0.480547  5  2.0
# 2013-01-04  0.848874  0.171807  1.497093  5  3.0
# 2013-01-05  0.450029 -1.042384  0.765347  5  4.0
# 2013-01-06 -0.757226  0.145115  0.211907  5  5.0

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.779058  0.205012 -0.564650   5   NaN
# 2013-01-02  1.746900  0.477374 -1.423678  10   1.0
# 2013-01-03  1.300687 -0.037267 -0.943131  15   3.0
# 2013-01-04  2.149560  0.134540  0.553963  20   6.0
# 2013-01-05  2.599589 -0.907844  1.319310  25  10.0
# 2013-01-06  1.842363 -0.762728  1.531217  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.725068
# B    1.314746
# C    2.356121
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    5
# 1    3
# 2    5
# 3    1
# 4    4
# 5    3
# 6    4
# 7    5
# 8    2
# 9    1
# dtype: int32

# %%
type(s.value_counts())
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.210710 -0.988994  1.970066  1.314558
# 1 -0.816463 -1.584171  0.898909 -0.210512
# 2 -1.245532  0.611788  0.386423 -0.264652
# 3  0.684221  0.793633 -1.331032 -0.582949
# 4 -0.399378  1.618468 -0.158459  0.601326
# 5  0.150489 -1.140857  2.058500 -1.069298
# 6  0.000597 -0.878398  0.469631 -0.370867
# 7 -0.247317 -0.395376 -0.328244 -0.258760
# 8 -1.305844  1.509447  0.209285  0.857314
# 9  0.619885 -0.117844  1.459627  0.175237

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  0.210710 -0.988994  1.970066  1.314558
#  1 -0.816463 -1.584171  0.898909 -0.210512
#  2 -1.245532  0.611788  0.386423 -0.264652,
#            0         1         2         3
#  3  0.684221  0.793633 -1.331032 -0.582949
#  4 -0.399378  1.618468 -0.158459  0.601326
#  5  0.150489 -1.140857  2.058500 -1.069298
#  6  0.000597 -0.878398  0.469631 -0.370867,
#            0         1         2         3
#  7 -0.247317 -0.395376 -0.328244 -0.258760
#  8 -1.305844  1.509447  0.209285  0.857314
#  9  0.619885 -0.117844  1.459627  0.175237]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.210710 -0.988994  1.970066  1.314558
# 1 -0.816463 -1.584171  0.898909 -0.210512
# 2 -1.245532  0.611788  0.386423 -0.264652
# 3  0.684221  0.793633 -1.331032 -0.582949
# 4 -0.399378  1.618468 -0.158459  0.601326
# 5  0.150489 -1.140857  2.058500 -1.069298
# 6  0.000597 -0.878398  0.469631 -0.370867
# 7 -0.247317 -0.395376 -0.328244 -0.258760
# 8 -1.305844  1.509447  0.209285  0.857314
# 9  0.619885 -0.117844  1.459627  0.175237

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left1 = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right1 = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
pd.merge(left1, right1, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.546875 -0.246971
# 1  bar    one  0.438649  1.566586
# 2  foo    two -1.184183  1.762606
# 3  bar  three -1.029396 -0.549163
# 4  foo    two  0.150185  0.448625
# 5  bar    two -1.330092 -0.978087
# 6  foo    one  1.170445 -0.004380
# 7  foo  three -0.647578  1.187103

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.438649  1.566586
#     three -1.029396 -0.549163
#     two   -1.330092 -0.978087
# foo one    1.717320 -0.251350
#     three -0.647578  1.187103
#     two   -1.033999  2.211231

# %%
tuples = list(
    zip(
        ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
        ["one", "two", "one", "two", "one", "two", "one", "two"],
    )
)
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df
# Out:
#                      A         B
# first second
# bar   one     0.364817  0.183831
#       two    -1.445747  0.742353
# baz   one     0.159296 -1.467740
#       two    -1.293181  0.000407
# foo   one     2.604869 -0.084159
#       two    -0.484214 -1.223225
# qux   one     0.005040  0.731787
#       two     1.291265  1.574227

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.364817  0.183831
#       two    -1.445747  0.742353
# baz   one     0.159296 -1.467740
#       two    -1.293181  0.000407

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    0.364817
#                B    0.183831
#        two     A   -1.445747
#                B    0.742353
# baz    one     A    0.159296
#                B   -1.467740
#        two     A   -1.293181
#                B    0.000407
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.364817  0.183831
#       two    -1.445747  0.742353
# baz   one     0.159296 -1.467740
#       two    -1.293181  0.000407

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.364817 -1.445747
#       B  0.183831  0.742353
# baz   A  0.159296 -1.293181
#       B -1.467740  0.000407

# %%
stacked.unstack().index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.810391  0.644392
# 1     one  B  foo -0.501979 -1.529686
# 2     two  C  foo -1.716646  1.657003
# 3   three  A  bar -1.584162 -0.391556
# 4     one  B  bar  0.455478 -0.169817
# 5     one  C  bar -1.047893 -0.481297
# 6     two  A  foo  0.590582 -1.474259
# 7   three  B  foo  0.381457  0.155081
# 8     one  C  foo  0.641500  0.629228
# 9     one  A  bar  0.500516 -1.477902
# 10    two  B  bar  0.153829  2.069463
# 11  three  C  bar  0.242081 -1.394503

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.500516  0.810391
#       B  0.455478 -0.501979
#       C -1.047893  0.641500
# three A -1.584162       NaN
#       B       NaN  0.381457
#       C  0.242081       NaN
# two   A       NaN  0.590582
#       B  0.153829       NaN
#       C       NaN -1.716646

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
type(rng)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
ts.sum()
# Out:
# 23115

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    23115
# Freq: 5T, dtype: int32

# %%
pd.date_range("1/1/2012", periods=100, freq="5T")
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:05:00',
#                '2012-01-01 00:10:00', '2012-01-01 00:15:00',
#                '2012-01-01 00:20:00', '2012-01-01 00:25:00',
#                '2012-01-01 00:30:00', '2012-01-01 00:35:00',
#                '2012-01-01 00:40:00', '2012-01-01 00:45:00',
#                '2012-01-01 00:50:00', '2012-01-01 00:55:00',
#                '2012-01-01 01:00:00', '2012-01-01 01:05:00',
#                '2012-01-01 01:10:00', '2012-01-01 01:15:00',
#                '2012-01-01 01:20:00', '2012-01-01 01:25:00',
#                '2012-01-01 01:30:00', '2012-01-01 01:35:00',
#                '2012-01-01 01:40:00', '2012-01-01 01:45:00',
#                '2012-01-01 01:50:00', '2012-01-01 01:55:00',
#                '2012-01-01 02:00:00', '2012-01-01 02:05:00',
#                '2012-01-01 02:10:00', '2012-01-01 02:15:00',
#                '2012-01-01 02:20:00', '2012-01-01 02:25:00',
#                '2012-01-01 02:30:00', '2012-01-01 02:35:00',
#                '2012-01-01 02:40:00', '2012-01-01 02:45:00',
#                '2012-01-01 02:50:00', '2012-01-01 02:55:00',
#                '2012-01-01 03:00:00', '2012-01-01 03:05:00',
#                '2012-01-01 03:10:00', '2012-01-01 03:15:00',
#                '2012-01-01 03:20:00', '2012-01-01 03:25:00',
#                '2012-01-01 03:30:00', '2012-01-01 03:35:00',
#                '2012-01-01 03:40:00', '2012-01-01 03:45:00',
#                '2012-01-01 03:50:00', '2012-01-01 03:55:00',
#                '2012-01-01 04:00:00', '2012-01-01 04:05:00',
#                '2012-01-01 04:10:00', '2012-01-01 04:15:00',
#                '2012-01-01 04:20:00', '2012-01-01 04:25:00',
#                '2012-01-01 04:30:00', '2012-01-01 04:35:00',
#                '2012-01-01 04:40:00', '2012-01-01 04:45:00',
#                '2012-01-01 04:50:00', '2012-01-01 04:55:00',
#                '2012-01-01 05:00:00', '2012-01-01 05:05:00',
#                '2012-01-01 05:10:00', '2012-01-01 05:15:00',
#                '2012-01-01 05:20:00', '2012-01-01 05:25:00',
#                '2012-01-01 05:30:00', '2012-01-01 05:35:00',
#                '2012-01-01 05:40:00', '2012-01-01 05:45:00',
#                '2012-01-01 05:50:00', '2012-01-01 05:55:00',
#                '2012-01-01 06:00:00', '2012-01-01 06:05:00',
#                '2012-01-01 06:10:00', '2012-01-01 06:15:00',
#                '2012-01-01 06:20:00', '2012-01-01 06:25:00',
#                '2012-01-01 06:30:00', '2012-01-01 06:35:00',
#                '2012-01-01 06:40:00', '2012-01-01 06:45:00',
#                '2012-01-01 06:50:00', '2012-01-01 06:55:00',
#                '2012-01-01 07:00:00', '2012-01-01 07:05:00',
#                '2012-01-01 07:10:00', '2012-01-01 07:15:00',
#                '2012-01-01 07:20:00', '2012-01-01 07:25:00',
#                '2012-01-01 07:30:00', '2012-01-01 07:35:00',
#                '2012-01-01 07:40:00', '2012-01-01 07:45:00',
#                '2012-01-01 07:50:00', '2012-01-01 07:55:00',
#                '2012-01-01 08:00:00', '2012-01-01 08:05:00',
#                '2012-01-01 08:10:00', '2012-01-01 08:15:00'],
#               dtype='datetime64[ns]', freq='5T')

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.376459
# 2012-03-07    0.261084
# 2012-03-08    0.862091
# 2012-03-09    0.562971
# 2012-03-10    1.873265
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.376459
# 2012-03-07 00:00:00+00:00    0.261084
# 2012-03-08 00:00:00+00:00    0.862091
# 2012-03-09 00:00:00+00:00    0.562971
# 2012-03-10 00:00:00+00:00    1.873265
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.376459
# 2012-03-06 19:00:00-05:00    0.261084
# 2012-03-07 19:00:00-05:00    0.862091
# 2012-03-08 19:00:00-05:00    0.562971
# 2012-03-09 19:00:00-05:00    1.873265
# Freq: D, dtype: float64

# %%
rng = pd.date_range("1/1/2012", periods=5, freq="M")

# %%
rng
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31   -0.901257
# 2012-02-29   -0.337193
# 2012-03-31   -1.219876
# 2012-04-30   -1.913655
# 2012-05-31    1.071779
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-01   -0.901257
# 2012-02   -0.337193
# 2012-03   -1.219876
# 2012-04   -1.913655
# 2012-05    1.071779
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.901257
# 2012-02-01   -0.337193
# 2012-03-01   -1.219876
# 2012-04-01   -1.913655
# 2012-05-01    1.071779
# Freq: MS, dtype: float64

# %%
prng = pd.period_range("1990Q1", "2000Q4", freq="Q-NOV")

# %%
prng
# Out:
# PeriodIndex(['1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1', '1991Q2',
#              '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3', '1992Q4',
#              '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1', '1994Q2',
#              '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3', '1995Q4',
#              '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1', '1997Q2',
#              '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3', '1998Q4',
#              '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1', '2000Q2',
#              '2000Q3', '2000Q4'],
#             dtype='period[Q-NOV]')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)
ts
# Out:
# 1990Q1   -0.392552
# 1990Q2   -0.125049
# 1990Q3    0.344868
# 1990Q4    0.063071
# 1991Q1   -0.711657
# 1991Q2    1.338721
# 1991Q3    1.738268
# 1991Q4   -0.689998
# 1992Q1    0.959937
# 1992Q2   -0.232036
# 1992Q3    0.107141
# 1992Q4   -0.867008
# 1993Q1   -1.696212
# 1993Q2    0.898099
# 1993Q3   -0.579632
# 1993Q4    1.439468
# 1994Q1    1.467584
# 1994Q2   -2.205349
# 1994Q3    0.771711
# 1994Q4   -1.805009
# 1995Q1   -0.755488
# 1995Q2    0.026741
# 1995Q3    2.187587
# 1995Q4    0.910901
# 1996Q1    0.641027
# 1996Q2    0.923979
# 1996Q3   -0.010114
# 1996Q4    0.864649
# 1997Q1   -1.172588
# 1997Q2    1.186517
# 1997Q3   -0.683117
# 1997Q4    0.053028
# 1998Q1    1.455080
# 1998Q2   -0.810980
# 1998Q3   -0.214474
# 1998Q4    1.328201
# 1999Q1    0.910640
# 1999Q2   -1.698542
# 1999Q3    0.049373
# 1999Q4   -1.085394
# 2000Q1   -0.275175
# 2000Q2   -1.430511
# 2000Q3   -0.037816
# 2000Q4   -0.628059
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -0.392552
# 1990-06-01 09:00   -0.125049
# 1990-09-01 09:00    0.344868
# 1990-12-01 09:00    0.063071
# 1991-03-01 09:00   -0.711657
# Freq: H, dtype: float64

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         b     b
# 3   4         a     a
# 4   5         a     a
# 5   6         e     e

# %%
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)
df["grade"] = df["raw_grade"].astype("category")

new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").count()
# Out:
#            id  raw_grade
# grade
# very bad    1          1
# bad         0          0
# medium      0          0
# good        2          2
# very good   3          3

# %%
import matplotlib.pyplot as plt
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts
# Out:
# 2000-01-01    0.593344
# 2000-01-02   -1.417150
# 2000-01-03    1.185468
# 2000-01-04    0.007767
# 2000-01-05    0.637571
#                 ...
# 2002-09-22   -1.017464
# 2002-09-23   -0.011248
# 2002-09-24    0.967736
# 2002-09-25   -0.852409
# 2002-09-26    1.755895
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts
# Out:
# 2000-01-01    0.593344
# 2000-01-02   -0.823805
# 2000-01-03    0.361662
# 2000-01-04    0.369429
# 2000-01-05    1.007000
#                 ...
# 2002-09-22   -9.717174
# 2002-09-23   -9.728423
# 2002-09-24   -8.760687
# 2002-09-25   -9.613096
# 2002-09-26   -7.857201
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.show()

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df
# Out:
#                    A         B         C         D
# 2000-01-01  1.470624 -2.401446 -0.863330  1.197009
# 2000-01-02  1.351997 -1.321270 -0.975982 -0.283553
# 2000-01-03  0.854382  0.041238  1.382084  0.499441
# 2000-01-04 -1.138229  1.037097  0.418163  0.016045
# 2000-01-05 -0.213776  1.156136 -0.032650 -1.138108
# ...              ...       ...       ...       ...
# 2002-09-22  0.911093 -0.937207 -0.022565  0.167808
# 2002-09-23 -0.489916  0.235194  0.293250  0.235321
# 2002-09-24  0.481210 -1.178323  0.599507 -1.307268
# 2002-09-25 -0.842526 -1.876447 -0.196950  0.829358
# 2002-09-26 -0.291917 -0.418633  0.455166 -1.124271
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()

# %%
df
# Out:
#                     A          B          C          D
# 2000-01-01   1.470624  -2.401446  -0.863330   1.197009
# 2000-01-02   2.822621  -3.722716  -1.839312   0.913457
# 2000-01-03   3.677003  -3.681478  -0.457228   1.412898
# 2000-01-04   2.538774  -2.644381  -0.039064   1.428943
# 2000-01-05   2.324998  -1.488244  -0.071715   0.290835
# ...               ...        ...        ...        ...
# 2002-09-22  48.411747 -24.954964 -13.428317  50.328499
# 2002-09-23  47.921831 -24.719770 -13.135068  50.563819
# 2002-09-24  48.403041 -25.898093 -12.535561  49.256552
# 2002-09-25  47.560515 -27.774540 -12.732511  50.085909
# 2002-09-26  47.268599 -28.193174 -12.277345  48.961639
#
# [1000 rows x 4 columns]

# %%
df.plot();
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.legend(loc='best');
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv("foo.csv")
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01   1.470624  -2.401446  -0.863330   1.197009
# 1    2000-01-02   2.822621  -3.722716  -1.839312   0.913457
# 2    2000-01-03   3.677003  -3.681478  -0.457228   1.412898
# 3    2000-01-04   2.538774  -2.644381  -0.039064   1.428943
# 4    2000-01-05   2.324998  -1.488244  -0.071715   0.290835
# ..          ...        ...        ...        ...        ...
# 995  2002-09-22  48.411747 -24.954964 -13.428317  50.328499
# 996  2002-09-23  47.921831 -24.719770 -13.135068  50.563819
# 997  2002-09-24  48.403041 -25.898093 -12.535561  49.256552
# 998  2002-09-25  47.560515 -27.774540 -12.732511  50.085909
# 999  2002-09-26  47.268599 -28.193174 -12.277345  48.961639
#
# [1000 rows x 5 columns]

# %%
df.to_hdf('foo.h5', 'df')

# %%
pd.read_hdf("foo.h5", "df")
# Out:
#                     A          B          C          D
# 2000-01-01   1.470624  -2.401446  -0.863330   1.197009
# 2000-01-02   2.822621  -3.722716  -1.839312   0.913457
# 2000-01-03   3.677003  -3.681478  -0.457228   1.412898
# 2000-01-04   2.538774  -2.644381  -0.039064   1.428943
# 2000-01-05   2.324998  -1.488244  -0.071715   0.290835
# ...               ...        ...        ...        ...
# 2002-09-22  48.411747 -24.954964 -13.428317  50.328499
# 2002-09-23  47.921831 -24.719770 -13.135068  50.563819
# 2002-09-24  48.403041 -25.898093 -12.535561  49.256552
# 2002-09-25  47.560515 -27.774540 -12.732511  50.085909
# 2002-09-26  47.268599 -28.193174 -12.277345  48.961639
#
# [1000 rows x 4 columns]

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#     Unnamed: 0          A          B          C          D
# 0   2000-01-01   1.470624  -2.401446  -0.863330   1.197009
# 1   2000-01-02   2.822621  -3.722716  -1.839312   0.913457
# 2   2000-01-03   3.677003  -3.681478  -0.457228   1.412898
# 3   2000-01-04   2.538774  -2.644381  -0.039064   1.428943
# 4   2000-01-05   2.324998  -1.488244  -0.071715   0.290835
# ..         ...        ...        ...        ...        ...
# 995 2002-09-22  48.411747 -24.954964 -13.428317  50.328499
# 996 2002-09-23  47.921831 -24.719770 -13.135068  50.563819
# 997 2002-09-24  48.403041 -25.898093 -12.535561  49.256552
# 998 2002-09-25  47.560515 -27.774540 -12.732511  50.085909
# 999 2002-09-26  47.268599 -28.193174 -12.277345  48.961639
#
# [1000 rows x 5 columns]

# %%
if pd.Series([False, True, False]):
    print('I was true')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [379], in <cell line: 1>()
# ----> 1 if pd.Series([False, True, False]):
#       2     print('I was true')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
